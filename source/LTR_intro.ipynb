# %% [markdown]
# # 1. Introduction to LTR(Learning to rank)
#
# LTR はLearning To Rank の頭文字です.
# 日本語では,ランキング学習やランク学習と呼ばれています．

# %% [markdown]
# ## 1.1 LTR(ランキング学習) ってなに?
#
# ランキング学習とは
# ランキング学習
# [wiki](https://en.wikipedia.org/wiki/Learning_to_rank)

# %% [markdown]
# ## 1.2 Learning To Rank のフレームワーク

# %% [markdown]
# ***
#
# ![LTRpict1](./pict/LTRpict1.png)
# 出典 :
#
# ***

# %% [markdown]
# 大体のLTRアルゴリズムは上の図のような仕組みとなっている.

# %% [markdown]
# ### 1.2.1 情報の整理
# 上の図の情報を整理する
#
# $$ q_{i} : クエリ i  $$
# $$ x  : 特徴ベクトル$$
# $$ y : 正解ラベル$$

# %% [markdown]
# ## 参考
#
# - [Learning to rank wiki](https://en.wikipedia.org/wiki/Learning_to_rank)
# - (https://opensourceconnections.com/blog/2017/02/24/what-is-learning-to-rank/)
