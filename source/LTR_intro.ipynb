# %% [markdown]
# <a href="https://colab.research.google.com/github/syokoysn/LTR/blob/master/source/LTR_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LTRって?
#
# LTR はLearning To Rank の頭文字です.
# つまりランキング学習のこと

# %% [markdown]
# ## Learning To Rank のフレームワーク

# %% [markdown]
# ![LTRpict1]()

# %% [markdown]
# $$ q_{i} : クエリ i  $$
# $$ x  : 特徴ベクトル$$
# $$y : $$

# %% [markdown]
# 大体のLTRアルゴリズムは上の図のような仕組みとなっている.
